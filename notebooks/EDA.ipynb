# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
pd.set_option("display.max_columns", None)
import numpy as np
from itertools import combinations

# %load_ext autoreload
# %autoreload 2
import sys
# Añadimos la carpeta que contiene nuestro .py al path de Python
sys.path.append("../src/")
import support_EDA as seda  # Importa la función desde el archivo

# Gráficos
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../results/all_products_info_with_categories.csv")
print(df.shape)
df.sample(3)
# Out:
# (118, 18)
#                        product_name  \
# 42            Pantalón jogger cargo
# 103  Pantalón jogger tejido plisado
# 7        Camiseta punto manga corta
#
#                                                    url  \
# 42   https://www.pullandbear.com/es/pantalon-jogger...
# 103  https://www.pullandbear.com/es/pantalon-jogger...
# 7    https://www.pullandbear.com/es/camiseta-punto-...
#
#                                             image1_url  \
# 42   https://static.pullandbear.net/2/photos//2024/...
# 103  https://static.pullandbear.net/assets/public/a...
# 7    https://static.pullandbear.net/2/photos//2024/...
#
#                                             image2_url  product_price  \
# 42   https://static.pullandbear.net/assets/public/5...          25.99
# 103  https://static.pullandbear.net/assets/public/7...          29.99
# 7    https://static.pullandbear.net/2/photos//2024/...           9.99
#
# ...

# %%
seda.exploracion_basica_dataframe(df)
# Out:
# El número de datos es 118 y el de columnas es 18
#
#  -------------------------------
#
# Los duplicados que tenemos en el conjunto de datos son: 0
#
#  -------------------------------
#
# Los unicos que tenemos en el conjunto de datos son:
#                      count  % unique
# url                    118    100.00
# image1_url             118    100.00
# image2_url             118    100.00
# image_url              116     98.31
# reference_code          64     54.24
# mpn                     64     54.24
# description             63     53.39
# product_name            59     50.00
# color                   35     29.66
# original_price          13     11.02
# color_homogeneizado     13     11.02
# product_price           10      8.47
# current_price           10      8.47
# category_id              6      5.08
# old_price                5      4.24
# Categoria                4      3.39
# sale_price               3      2.54
# Stock Status             2      1.69
# ...

# %% [markdown]
# A la vista de los datos procedemos a realizar el preprocesing

# %%
# Limpieza de duplicados
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (442, 38)

# %%
df.head(1)
# Out:
#                  product_name  \
# 0  Camiseta punto manga corta
#
#                                                  url  \
# 0  https://www.pullandbear.com/es/camiseta-punto-...
#
#                                           image1_url  \
# 0  https://static.pullandbear.net/2/photos//2024/...
#
#                                           image2_url  product_price  \
# 0  https://static.pullandbear.net/2/photos//2024/...           9.99
#
#                                          description  sale_price  old_price  \
# 0  Camiseta de punto básico de manga corta, con c...        9.99      12.99
#
#    original_price  current_price  color  \
# 0           15.99           9.99  Rayas
#
#                                            image_url       mpn  \
# 0  https://static.pullandbear.net/2/photos//2024/...  3555/512
#
#    reference_code   category_id Stock Status color_homogeneizado Categoria
# 0       3555512.0  1.030205e+09     In stock          Multicolor  Camiseta

# %%
# Elimino las variables que en el EDA preliminar cumplen los siguientes requisitos:
df2=df.drop(columns=[
"url", # No aporta
"image1_url", # No aporta
"image2_url", # No aporta
"product_price", # Valor repetido
"image_url", # No aporta
])
df2.sample(5)
# Out:
#                               product_name  \
# 41                   Pantalón chándal STWD
# 24          Camiseta Red Hot Chili Peppers
# 93                 Pantalón chándal skater
# 47                  Pantalón chándal baggy
# 65  Pantalón chándal interlock super baggy
#
#                                           description  sale_price  old_price  \
# 41  Pantalón jogger chándal STWD con cintura elást...         NaN        NaN
# 24  Camiseta licencia de Red Hot Chili Peppers con...        3.99       7.99
# 93  Pantalón jogger de corte skater en tejido efec...         NaN        NaN
# 47  Pantalón de chándal jogger de corte baggy, con...         NaN        NaN
# 65  Pantalón de chándal balloon fit y en tejido in...         NaN        NaN
#
#     original_price  current_price        color       mpn  reference_code  \
# 41             NaN          19.99  Gris vigoré  7678/506       7678506.0
# 24           17.99           3.99  Blanco roto  3243/929       3243929.0
# ...

# %%
seda.plot_categoricas(df2,max_categories=50)
# Out:
# c:\Users\alexc\Desktop\GIT\ProyectoFinal-HACKIO\notebooks\../src\support_EDA.py:165: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# c:\Users\alexc\Desktop\GIT\ProyectoFinal-HACKIO\notebooks\../src\support_EDA.py:162: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   combined_counts = pd.concat([category_counts, null_series])
# c:\Users\alexc\Desktop\GIT\ProyectoFinal-HACKIO\notebooks\../src\support_EDA.py:165: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# ...

# %%
seda.plot_numericas(df2)

# %%
seda.matriz_correlacion(df2)

# %%
seda.relacion_vr_categoricas(df2, "current_price")
# Out:
# c:\Users\alexc\Desktop\GIT\ProyectoFinal-HACKIO\notebooks\../src\support_EDA.py:205: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# c:\Users\alexc\Desktop\GIT\ProyectoFinal-HACKIO\notebooks\../src\support_EDA.py:205: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
