# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import sys
# Añadimos la carpeta que contiene nuestro .py al path de Python
sys.path.append("../src/")
import support_scrap as ss
import support_mongo as sm
import support_filter_models as sfm
# Out:
# WARNING:tensorflow:From C:\Users\alexc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at facebook/dino-vitb16 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu

# %%
# URLs a procesar

listaurl = [
    "https://www.pullandbear.com/es/hombre/ropa/camisetas-n6323",
    "https://www.pullandbear.com/es/hombre/rebajas/ropa/camisetas-y-polos-n7087",
    "https://www.pullandbear.com/es/hombre/ropa/camisas-n6313",
    "https://www.pullandbear.com/es/hombre/rebajas/ropa/camisas-n7088",
    "https://www.pullandbear.com/es/hombre/ropa/punto-n6372",
    "https://www.pullandbear.com/es/hombre/rebajas/ropa/punto-n7090",
    "https://www.pullandbear.com/es/hombre/ropa/sudaderas-n6382",
    "https://www.pullandbear.com/es/hombre/rebajas/ropa/sudaderas-n7089",
    "https://www.pullandbear.com/es/hombre/ropa/pantalones-n6363",
    "https://www.pullandbear.com/es/hombre/rebajas/ropa/pantalones-n7091",
    "https://www.pullandbear.com/es/hombre/ropa/jeans-n6347",
    "https://www.pullandbear.com/es/hombre/rebajas/ropa/jeans-n7818"
]

df_nuevo = ss.process_and_extract_data_main(listaurl)

# Mostrar articulos antes y despues
print("Articulos actuales:")
print(df_nuevo.shape)

# Mostrar el DataFrame
df_nuevo.head()
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# Cookies aceptadas
#   8%|▊         | 1/12 [00:25<04:39, 25.42s/it]
# Se han encontrado 103 productos en https://www.pullandbear.com/es/hombre/ropa/camisetas-n6323
# No se encontró el botón de cookies o ya estaban aceptadas
#  17%|█▋        | 2/12 [00:38<03:00, 18.04s/it]
# Se han encontrado 29 productos en https://www.pullandbear.com/es/hombre/rebajas/ropa/camisetas-y-polos-n7087
# No se encontró el botón de cookies o ya estaban aceptadas
#  25%|██▌       | 3/12 [00:47<02:04, 13.80s/it]
# Se han encontrado 15 productos en https://www.pullandbear.com/es/hombre/ropa/camisas-n6313
# No se encontró el botón de cookies o ya estaban aceptadas
#  33%|███▎      | 4/12 [01:03<01:58, 14.82s/it]
# Se han encontrado 64 productos en https://www.pullandbear.com/es/hombre/rebajas/ropa/camisas-n7088
# No se encontró el botón de cookies o ya estaban aceptadas
#  42%|████▏     | 5/12 [01:14<01:33, 13.31s/it]
# Se han encontrado 22 productos en https://www.pullandbear.com/es/hombre/ropa/punto-n6372
# No se encontró el botón de cookies o ya estaban aceptadas
#  50%|█████     | 6/12 [01:17<01:00, 10.11s/it]
# Se han encontrado 0 productos en https://www.pullandbear.com/es/hombre/rebajas/ropa/punto-n7090
# No se encontró el botón de cookies o ya estaban aceptadas
#  58%|█████▊    | 7/12 [01:48<01:23, 16.76s/it]
# Se han encontrado 139 productos en https://www.pullandbear.com/es/hombre/ropa/sudaderas-n6382
# No se encontró el botón de cookies o ya estaban aceptadas
#  67%|██████▋   | 8/12 [02:08<01:11, 17.86s/it]
# Se han encontrado 72 productos en https://www.pullandbear.com/es/hombre/rebajas/ropa/sudaderas-n7089
# No se encontró el botón de cookies o ya estaban aceptadas
#  75%|███████▌  | 9/12 [02:24<00:52, 17.34s/it]
# Se han encontrado 47 productos en https://www.pullandbear.com/es/hombre/ropa/pantalones-n6363
# No se encontró el botón de cookies o ya estaban aceptadas
#  83%|████████▎ | 10/12 [02:52<00:40, 20.43s/it]
# Se han encontrado 112 productos en https://www.pullandbear.com/es/hombre/rebajas/ropa/pantalones-n7091
# No se encontró el botón de cookies o ya estaban aceptadas
#  92%|█████████▏| 11/12 [03:11<00:20, 20.11s/it]
# Se han encontrado 72 productos en https://www.pullandbear.com/es/hombre/ropa/jeans-n6347
# No se encontró el botón de cookies o ya estaban aceptadas
# 100%|██████████| 12/12 [03:15<00:00, 16.30s/it]
# Se han encontrado 0 productos en https://www.pullandbear.com/es/hombre/rebajas/ropa/jeans-n7818
# Articulos actuales:
# (675, 5)
#               product_name                                                url  \
# 0     Camiseta Thomas Lélu  https://www.pullandbear.com/es/camiseta-thomas...
# 1  Camiseta Peanuts blanca  https://www.pullandbear.com/es/camiseta-peanut...
# 2       Polo Peanuts rayas  https://www.pullandbear.com/es/polo-peanuts-ra...
# 3   Camiseta Peanuts verde  https://www.pullandbear.com/es/camiseta-peanut...
# 4            Camiseta boxy  https://www.pullandbear.com/es/camiseta-boxy-l...
#
#                                           image1_url  \
# 0  https://static.pullandbear.net/assets/public/d...
# 1  https://static.pullandbear.net/assets/public/7...
# 2  https://static.pullandbear.net/assets/public/0...
# 3  https://static.pullandbear.net/assets/public/3...
# 4  https://static.pullandbear.net/assets/public/a...
#
#                                           image2_url  product_price
# 0  https://static.pullandbear.net/assets/public/0...          17.99
# 1  https://static.pullandbear.net/assets/public/d...          15.99
# 2  https://static.pullandbear.net/assets/public/b...          22.99
# 3  https://static.pullandbear.net/assets/public/4...          15.99
# 4  https://static.pullandbear.net/assets/public/7...          12.99

# %%
# Ejecutamos la funcion de scrapeo de productos
df_results=ss.process_urls_products(df_nuevo)

# Unir los DataFrames utilizando la columna 'url'
df_successful=pd.merge(df_nuevo,df_results,on='url', how='inner')

# Columnas clave para identificar duplicados
columnas_clave = ['product_price','description','current_price','color','image_url','mpn','reference_code','category_id']

# Crear un DataFrame con los duplicados eliminados
df_sin_duplicados = df_successful.drop_duplicates(subset=columnas_clave, keep='first')

# Mostrar resultados
print("Resultados:")
print(df_successful.shape)
print("Resultados sin duplicados:")
print(df_sin_duplicados.shape)
df_sin_duplicados.head()
# Out:
#  19%|█▉        | 128/675 [04:09<24:54,  2.73s/it]
# Error procesando la URL https://www.pullandbear.com/es/sudadera-manga-corta-paris-l07248592?cS=251&pelement=621948362: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  19%|█▉        | 129/675 [04:15<32:38,  3.59s/it]
# Error procesando la URL https://www.pullandbear.com/es/camiseta-grafico-calavera-l07248586?cS=696&pelement=621948281: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  20%|█▉        | 132/675 [04:24<33:17,  3.68s/it]
# Error procesando la URL https://www.pullandbear.com/es/camiseta-manga-corta-otoman-l03241586?cS=500&pelement=621934887: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  23%|██▎       | 157/675 [05:14<25:13,  2.92s/it]
# Error procesando la URL https://www.pullandbear.com/es/camisa-franela-pb-black-label-l07470517?cS=717&pelement=628555101: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  28%|██▊       | 192/675 [06:24<24:25,  3.03s/it]
# Error procesando la URL https://www.pullandbear.com/es/camisa-cuadros-stwd-l07470508?cS=511&pelement=624823200: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  29%|██▉       | 198/675 [06:39<25:52,  3.25s/it]
# Error procesando la URL https://www.pullandbear.com/es/camisa-cuadros-boxy-l07470528?cS=800&pelement=650687050: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  58%|█████▊    | 393/675 [12:57<12:37,  2.69s/it]
# Error procesando la URL https://www.pullandbear.com/es/sudadera-capucha-stwd-garage-l07590518?cS=806&pelement=627888234: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  59%|█████▉    | 399/675 [13:11<13:36,  2.96s/it]
# Error procesando la URL https://www.pullandbear.com/es/jersey-oversize-calado-lavado-acido-l07554525?cS=089&pelement=633467286: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  62%|██████▏   | 417/675 [13:44<12:47,  2.98s/it]
# Error procesando la URL https://www.pullandbear.com/es/cardigan-punto-soft-pb-black-label-l07554526?cS=401&pelement=641209153: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  65%|██████▍   | 436/675 [14:20<11:13,  2.82s/it]
# Error procesando la URL https://www.pullandbear.com/es/jersey-stwd-costuras-l07554509?cS=505&pelement=641676154: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  65%|██████▌   | 442/675 [14:34<11:44,  3.02s/it]
# Error procesando la URL https://www.pullandbear.com/es/sudadera-manga-corta-paris-l07248592?cS=251&pelement=621948362: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  76%|███████▌  | 512/675 [16:46<07:41,  2.83s/it]
# Error procesando la URL https://www.pullandbear.com/es/pantalon-slouchy-pb-black-label-l07678534?cS=802&pelement=630355649: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
#  85%|████████▍ | 571/675 [18:48<08:05,  4.67s/it]
# Error procesando la URL https://www.pullandbear.com/es/jeans-baggy-l07685519?cS=712&pelement=621956723: Message:
# Stacktrace:
# 	GetHandleVerifier [0x002E74A3+25091]
# 	(No symbol) [0x0026DC04]
# 	(No symbol) [0x0014B373]
# 	(No symbol) [0x0018F4DC]
# 	(No symbol) [0x0018F65B]
# 	(No symbol) [0x001CD8E2]
# 	(No symbol) [0x001B1F54]
# 	(No symbol) [0x001CB49E]
# 	(No symbol) [0x001B1CA6]
# 	(No symbol) [0x001831D5]
# 	(No symbol) [0x0018435D]
# 	GetHandleVerifier [0x005E07C3+3142947]
# 	GetHandleVerifier [0x005F1A2B+3213195]
# 	GetHandleVerifier [0x005EC412+3191154]
# 	GetHandleVerifier [0x00388720+685184]
# 	(No symbol) [0x00276E1D]
# 	(No symbol) [0x00273E18]
# 	(No symbol) [0x00273FB6]
# 	(No symbol) [0x002666F0]
# 	BaseThreadInitThunk [0x76927BA9+25]
# 	RtlInitializeExceptionChain [0x776AC0CB+107]
# 	RtlClearBits [0x776AC04F+191]
# 	(No symbol) [0x00000000]
# 100%|██████████| 675/675 [22:12<00:00,  1.97s/it]
# Resultados:
# (737, 16)
# Resultados sin duplicados:
# (620, 16)
#               product_name                                                url  \
# 0     Camiseta Thomas Lélu  https://www.pullandbear.com/es/camiseta-thomas...
# 1  Camiseta Peanuts blanca  https://www.pullandbear.com/es/camiseta-peanut...
# 2       Polo Peanuts rayas  https://www.pullandbear.com/es/polo-peanuts-ra...
# 3   Camiseta Peanuts verde  https://www.pullandbear.com/es/camiseta-peanut...
# 4            Camiseta boxy  https://www.pullandbear.com/es/camiseta-boxy-l...
#
#                                           image1_url  \
# 0  https://static.pullandbear.net/assets/public/d...
# 1  https://static.pullandbear.net/assets/public/7...
# 2  https://static.pullandbear.net/assets/public/0...
# 3  https://static.pullandbear.net/assets/public/3...
# 4  https://static.pullandbear.net/assets/public/a...
#
#                                           image2_url  product_price  \
# 0  https://static.pullandbear.net/assets/public/0...          17.99
# 1  https://static.pullandbear.net/assets/public/d...          15.99
# 2  https://static.pullandbear.net/assets/public/b...          22.99
# 3  https://static.pullandbear.net/assets/public/4...          15.99
# 4  https://static.pullandbear.net/assets/public/7...          12.99
#
#                                          description  sale_price  old_price  \
# 0  Camiseta blanca de manga corta licencia Thomas...         NaN        NaN
# 1  Camiseta licencia Peanuts de color blanco con ...         NaN        NaN
# 2  Polo licencia Peanuts con diseño a rayas, de m...         NaN        NaN
# 3  Camiseta licencia Peanuts de color verde con g...         NaN        NaN
# 4  Camiseta boxy de manga corta con cuello redond...         NaN        NaN
#
#    original_price  current_price        color  \
# 0             NaN          17.99       Blanco
# 1             NaN          15.99  Blanco roto
# 2             NaN          22.99        Rayas
# 3             NaN          15.99        Verde
# 4             NaN          12.99        Negro
#
#                                            image_url       mpn reference_code  \
# 0  https://static.pullandbear.net/assets/public/4...  3245/574       03245574
# 1  https://static.pullandbear.net/assets/public/3...  3245/567       03245567
# 2  https://static.pullandbear.net/assets/public/5...  3245/565       03245565
# 3  https://static.pullandbear.net/assets/public/2...  3245/566       03245566
# 4  https://static.pullandbear.net/assets/public/f...  3248/501       03248501
#
#   category_id Stock Status
# 0  1030139501     In stock
# 1  1030139501     In stock
# 2  1030139501     In stock
# 3  1030139501     In stock
# 4  1030204791     In stock

# %% [markdown]
# # HOMOGENEIZAR LOS DATOS

# %% [markdown]
# ### COLOR

# %%
# Crear una nueva columna con el color homogeneizado
df_sin_duplicados['color_homogeneizado'] = df_sin_duplicados['color'].apply(ss.homogeneizar_color)
# Out:
# C:\Users\alexc\AppData\Local\Temp\ipykernel_9540\3346448002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados['color_homogeneizado'] = df_sin_duplicados['color'].apply(ss.homogeneizar_color)

# %% [markdown]
# ### CATEGORÍA

# %%
# Crear una nueva columna con la categoría de la prenda
df_sin_duplicados['Categoria'] = df_sin_duplicados['product_name'].apply(ss.categorizar_ropa)

# Mostrar las primeras filas para comprobar
df_sin_duplicados[['product_name', 'Categoria']].sample(5)
# Out:
# C:\Users\alexc\AppData\Local\Temp\ipykernel_9540\448092441.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados['Categoria'] = df_sin_duplicados['product_name'].apply(ss.categorizar_ropa)
#                                 product_name Categoria
# 579                Jeans baggy detalle rotos  Pantalón
# 242                      Jersey bordado STWD    Jersey
# 175                     Camisa rayas cropped    Camisa
# 568                          Jeans loose fit  Pantalón
# 74   Sudadera manga corta Girasoles Van Gogh  Camiseta

# %% [markdown]
# ### CONTROL URLs FALTANTES

# %%
# Asignar "out of stock" a la columna 'Stock Status' donde 'image_url' sea vacío o nulo
df_sin_duplicados.loc[(df_sin_duplicados['image_url'].isna()) | (df_sin_duplicados['image_url'] == ''), 'Stock Status'] = 'Out of Stock'

# %% [markdown]
# ### GUARDAR CSV

# %%
# Filtrar los pantalones para coger los modelos de cuerpo entero
df_modelos = df_sin_duplicados[(df_sin_duplicados['Categoria'] == 'Pantalón')]
df_modelos["Fondo"] =df_modelos["image1_url"].apply(sfm.is_white_background)
df_modelos["Modelo"] =df_modelos["image1_url"].apply(sfm.classify_image)
df_modelos_final=df_modelos[(df_modelos["Fondo"] == "Blanco")&(df_modelos["Modelo"] == "Modelo")&(df_modelos["Stock Status"] == "In stock")]
# Out:
# C:\Users\alexc\AppData\Local\Temp\ipykernel_9540\4263403506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_modelos["Fondo"] =df_modelos["image1_url"].apply(sfm.is_white_background)
# 0: 640x448 1 person, 1 tie, 164.2ms
# Speed: 20.5ms preprocess, 164.2ms inference, 17.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.8ms
# Speed: 2.0ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 53.9ms
# Speed: 2.5ms preprocess, 53.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.7ms
# Speed: 2.4ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.9ms
# Speed: 3.0ms preprocess, 54.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.6ms
# Speed: 1.0ms preprocess, 57.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.4ms
# Speed: 1.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.8ms
# Speed: 4.0ms preprocess, 55.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.7ms
# Speed: 2.5ms preprocess, 57.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 64.2ms
# Speed: 2.2ms preprocess, 64.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.6ms
# Speed: 0.0ms preprocess, 56.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 2.5ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 2 persons, 2 ties, 64.3ms
# Speed: 1.5ms preprocess, 64.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.9ms
# Speed: 2.3ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.5ms
# Speed: 1.5ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.5ms
# Speed: 2.5ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.9ms
# Speed: 2.0ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.9ms
# Speed: 2.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 tie, 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.7ms
# Speed: 2.0ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.1ms
# Speed: 2.5ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.8ms
# Speed: 2.5ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.2ms
# Speed: 3.0ms preprocess, 61.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 tie, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 63.8ms
# Speed: 2.5ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.8ms
# Speed: 2.1ms preprocess, 60.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.7ms
# Speed: 2.5ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 72.5ms
# Speed: 2.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.3ms
# Speed: 1.5ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.3ms
# Speed: 2.1ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.2ms
# Speed: 3.0ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.3ms
# Speed: 2.5ms preprocess, 58.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.4ms
# Speed: 2.6ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.3ms
# Speed: 2.0ms preprocess, 57.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.7ms
# Speed: 2.5ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.1ms
# Speed: 2.5ms preprocess, 56.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 66.2ms
# Speed: 2.0ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.2ms
# Speed: 2.4ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 tie, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.8ms
# Speed: 2.0ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.3ms
# Speed: 3.1ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.9ms
# Speed: 3.0ms preprocess, 57.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 tie, 58.8ms
# Speed: 1.5ms preprocess, 58.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.7ms
# Speed: 2.9ms preprocess, 62.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.6ms
# Speed: 1.0ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 73.5ms
# Speed: 47.1ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 66.9ms
# Speed: 2.0ms preprocess, 66.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.2ms
# Speed: 3.1ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.0ms
# Speed: 3.5ms preprocess, 60.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 99.7ms
# Speed: 2.0ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.3ms
# Speed: 3.4ms preprocess, 59.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.9ms
# Speed: 2.5ms preprocess, 58.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.9ms
# Speed: 2.0ms preprocess, 59.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.2ms
# Speed: 2.0ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.2ms
# Speed: 3.0ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.9ms
# Speed: 3.0ms preprocess, 58.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 70.3ms
# Speed: 2.5ms preprocess, 70.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.4ms
# Speed: 2.5ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.4ms
# Speed: 2.5ms preprocess, 59.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.2ms
# Speed: 1.0ms preprocess, 59.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.3ms
# Speed: 1.5ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.4ms
# Speed: 1.5ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.6ms
# Speed: 3.0ms preprocess, 61.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 112.5ms
# Speed: 2.5ms preprocess, 112.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 67.2ms
# Speed: 3.0ms preprocess, 67.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.9ms
# Speed: 2.5ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.2ms
# Speed: 2.0ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.2ms
# Speed: 1.5ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.8ms
# Speed: 3.0ms preprocess, 57.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.3ms
# Speed: 2.5ms preprocess, 58.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.7ms
# Speed: 3.0ms preprocess, 57.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 2 ties, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.2ms
# Speed: 3.0ms preprocess, 60.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.8ms
# Speed: 2.5ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 63.5ms
# Speed: 1.5ms preprocess, 63.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 71.5ms
# Speed: 2.3ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.9ms
# Speed: 2.5ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.5ms
# Speed: 2.5ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 tie, 61.6ms
# Speed: 2.5ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 66.3ms
# Speed: 2.6ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.9ms
# Speed: 2.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 71.6ms
# Speed: 46.9ms preprocess, 71.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.5ms
# Speed: 2.5ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.1ms
# Speed: 2.5ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 76.1ms
# Speed: 1.5ms preprocess, 76.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.8ms
# Speed: 2.5ms preprocess, 59.8ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.1ms
# Speed: 2.5ms preprocess, 61.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.2ms
# Speed: 2.0ms preprocess, 61.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.4ms
# Speed: 2.0ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.2ms
# Speed: 1.5ms preprocess, 61.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 63.3ms
# Speed: 2.5ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.4ms
# Speed: 2.4ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.3ms
# Speed: 3.0ms preprocess, 61.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 tie, 63.9ms
# Speed: 1.0ms preprocess, 63.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.5ms
# Speed: 3.1ms preprocess, 58.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 382.3ms
# Speed: 2.0ms preprocess, 382.3ms inference, 11.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 573.0ms
# Speed: 19.3ms preprocess, 573.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 511.0ms
# Speed: 16.7ms preprocess, 511.0ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 416.0ms
# Speed: 15.2ms preprocess, 416.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 470.4ms
# Speed: 13.7ms preprocess, 470.4ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 475.0ms
# Speed: 16.5ms preprocess, 475.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 61.6ms
# Speed: 1.5ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.9ms
# Speed: 1.8ms preprocess, 61.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.3ms
# Speed: 1.9ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.9ms
# Speed: 3.0ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.9ms
# Speed: 2.5ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.7ms
# Speed: 2.1ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.2ms
# Speed: 2.4ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.7ms
# Speed: 2.1ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.2ms
# Speed: 1.5ms preprocess, 59.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 64.5ms
# Speed: 3.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.9ms
# Speed: 2.5ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.3ms
# Speed: 2.5ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.2ms
# Speed: 3.0ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.9ms
# Speed: 2.5ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 71.8ms
# Speed: 46.9ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.2ms
# Speed: 2.0ms preprocess, 61.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.9ms
# Speed: 2.5ms preprocess, 59.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.3ms
# Speed: 2.1ms preprocess, 58.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.7ms
# Speed: 2.0ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.7ms
# Speed: 2.0ms preprocess, 60.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.7ms
# Speed: 2.0ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.9ms
# Speed: 2.0ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.0ms
# Speed: 1.5ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 2 ties, 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.4ms
# Speed: 3.0ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.6ms
# Speed: 1.5ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.2ms
# Speed: 2.0ms preprocess, 61.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.5ms
# Speed: 2.4ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.7ms
# Speed: 2.0ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.3ms
# Speed: 2.0ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 68.4ms
# Speed: 2.5ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.3ms
# Speed: 2.0ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.9ms
# Speed: 2.5ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.8ms
# Speed: 1.5ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.5ms
# Speed: 2.5ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.7ms
# Speed: 1.0ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.0ms
# Speed: 2.5ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.6ms
# Speed: 1.5ms preprocess, 62.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
# C:\Users\alexc\AppData\Local\Temp\ipykernel_9540\4263403506.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_modelos["Modelo"] =df_modelos["image1_url"].apply(sfm.classify_image)

# %%
# Guardar el nuevo DataFrame con pantalones en un archivo CSV
df_modelos_final.to_csv('../results/Modelos_enteros.csv', index=False)
df_modelos.to_csv('../results/Modelos_entero_sin_filtro.csv', index=False)

# Guardar los cambios en un archivo nuevo si lo necesitas
df_sin_duplicados.to_csv('../results/all_products_info_with_categories.csv', index=False)

# %% [markdown]
# ### SUBIR A MONGODB

# %%
# Guardamos los datos en la bbdd de Mongo
bd=sm.conectar_a_mongo("PullnBearData")
nombre_coleccion1="modelos_pull_hombre"
nombre_coleccion2="productos_pull_hombre"
sm.eliminar_coleccion(bd, nombre_coleccion1)
sm.subir_dataframe_a_mongo(bd, df_modelos_final, nombre_coleccion1)
sm.eliminar_coleccion(bd, nombre_coleccion2)
sm.subir_dataframe_a_mongo(bd, df_sin_duplicados, nombre_coleccion2)
# Out:
# DataFrame subido a la colección: modelos_pull_hombre
# DataFrame subido a la colección: productos_pull_hombre
