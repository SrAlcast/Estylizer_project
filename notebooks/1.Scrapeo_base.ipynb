# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import sys
# Añadimos la carpeta que contiene nuestro .py al path de Python
sys.path.append("../src/")
import support_scrap as ss
import support_mongo as sm
import support_filter_models as sfm
# Out:
# WARNING:tensorflow:From C:\Users\alexc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at facebook/dino-vitb16 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu

# %%
# URLs a procesar

listaurl = [
    "https://www.pullandbear.com/es/hombre/ropa/camisetas-n6323",
    "https://www.pullandbear.com/es/hombre/ropa/camisas-n6313",
    "https://www.pullandbear.com/es/hombre/ropa/punto-n6372",
    "https://www.pullandbear.com/es/hombre/ropa/sudaderas-n6382",
    "https://www.pullandbear.com/es/hombre/ropa/pantalones-n6363",
    "https://www.pullandbear.com/es/hombre/ropa/jeans-n6347",
    "https://www.pullandbear.com/es/hombre/rebajas/favoritos-n7255"
]

df_nuevo = ss.process_and_extract_data_main(listaurl)

# Mostrar articulos antes y despues
print("Articulos actuales:")
print(df_nuevo.shape)

# Mostrar el DataFrame
df_nuevo.head()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Cookies aceptadas
#  14%|█▍        | 1/7 [00:27<02:43, 27.26s/it]
# Se han encontrado 119 productos en https://www.pullandbear.com/es/hombre/ropa/camisetas-n6323
# No se encontró el botón de cookies o ya estaban aceptadas
#  29%|██▊       | 2/7 [00:37<01:26, 17.29s/it]
# Se han encontrado 19 productos en https://www.pullandbear.com/es/hombre/ropa/camisas-n6313
# No se encontró el botón de cookies o ya estaban aceptadas
#  43%|████▎     | 3/7 [00:48<00:57, 14.37s/it]
# Se han encontrado 25 productos en https://www.pullandbear.com/es/hombre/ropa/punto-n6372
# No se encontró el botón de cookies o ya estaban aceptadas
#  57%|█████▋    | 4/7 [01:19<01:03, 21.06s/it]
# Se han encontrado 143 productos en https://www.pullandbear.com/es/hombre/ropa/sudaderas-n6382
# No se encontró el botón de cookies o ya estaban aceptadas
#  71%|███████▏  | 5/7 [01:36<00:39, 19.55s/it]
# Se han encontrado 59 productos en https://www.pullandbear.com/es/hombre/ropa/pantalones-n6363
# No se encontró el botón de cookies o ya estaban aceptadas
#  86%|████████▌ | 6/7 [01:56<00:19, 19.69s/it]
# Se han encontrado 77 productos en https://www.pullandbear.com/es/hombre/ropa/jeans-n6347
# No se encontró el botón de cookies o ya estaban aceptadas
# 100%|██████████| 7/7 [02:27<00:00, 21.06s/it]
# Se han encontrado 139 productos en https://www.pullandbear.com/es/hombre/rebajas/favoritos-n7255
# Articulos actuales:
# (581, 5)
#                  product_name  \
# 0    Camiseta Bialetti blanca
# 1              Camiseta Honda
# 2     Camiseta Sakamoto Store
# 3  Camiseta básica muscle fit
# 4  Camiseta básica muscle fit
#
#                                                  url  \
# 0  https://www.pullandbear.com/es/camiseta-bialet...
# 1  https://www.pullandbear.com/es/camiseta-honda-...
# 2  https://www.pullandbear.com/es/camiseta-sakamo...
# 3  https://www.pullandbear.com/es/camiseta-basica...
# 4  https://www.pullandbear.com/es/camiseta-basica...
#
#                                           image1_url  \
# 0  https://static.pullandbear.net/assets/public/f...
# 1  https://static.pullandbear.net/assets/public/f...
# 2  https://static.pullandbear.net/assets/public/8...
# 3  https://static.pullandbear.net/assets/public/4...
# 4  https://static.pullandbear.net/assets/public/3...
#
#                                           image2_url  product_price
# 0  https://static.pullandbear.net/assets/public/d...          15.99
# 1  https://static.pullandbear.net/2/photos//2025/...          15.99
# 2  https://static.pullandbear.net/assets/public/c...          17.99
# 3  https://static.pullandbear.net/assets/public/f...           7.99
# 4  https://static.pullandbear.net/assets/public/5...           7.99

# %%
# Ejecutamos la funcion de scrapeo de productos
df_results=ss.process_urls_products(df_nuevo)

# Unir los DataFrames utilizando la columna 'url'
df_successful=pd.merge(df_nuevo,df_results,on='url', how='inner')

# Columnas clave para identificar duplicados
columnas_clave = ['product_price','description','current_price','color','image_url','mpn','reference_code','category_id']

# Crear un DataFrame con los duplicados eliminados
df_sin_duplicados = df_successful.drop_duplicates(subset=columnas_clave, keep='first')

# Mostrar resultados
print("Resultados:")
print(df_successful.shape)
print("Resultados sin duplicados:")
print(df_sin_duplicados.shape)
df_sin_duplicados.head()
# Out:
#  15%|█▌        | 89/581 [02:28<23:17,  2.84s/it]
# Error procesando la URL https://www.pullandbear.com/es/camiseta-manga-larga-thomas-lelu-l03245393?cS=805&pelement=680333902: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00B374A3+25091]
# 	(No symbol) [0x00ABDC04]
# 	(No symbol) [0x0099B373]
# 	(No symbol) [0x009DF4DC]
# 	(No symbol) [0x009DF65B]
# 	(No symbol) [0x00A1D8E2]
# 	(No symbol) [0x00A01F54]
# 	(No symbol) [0x00A1B49E]
# 	(No symbol) [0x00A01CA6]
# 	(No symbol) [0x009D31D5]
# 	(No symbol) [0x009D435D]
# 	GetHandleVerifier [0x00E307C3+3142947]
# 	GetHandleVerifier [0x00E41A2B+3213195]
# 	GetHandleVerifier [0x00E3C412+3191154]
# 	GetHandleVerifier [0x00BD8720+685184]
# 	(No symbol) [0x00AC6E1D]
# 	(No symbol) [0x00AC3E18]
# 	(No symbol) [0x00AC3FB6]
# 	(No symbol) [0x00AB66F0]
# 	BaseThreadInitThunk [0x75077BA9+25]
# 	RtlInitializeExceptionChain [0x76EBC0CB+107]
# 	RtlClearBits [0x76EBC04F+191]
#  26%|██▌       | 152/581 [04:24<23:43,  3.32s/it]
# Error procesando la URL https://www.pullandbear.com/es/jersey-cuello-cremallera-l07554517?cS=250: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00B374A3+25091]
# 	(No symbol) [0x00ABDC04]
# 	(No symbol) [0x0099B373]
# 	(No symbol) [0x009DF4DC]
# 	(No symbol) [0x009DF65B]
# 	(No symbol) [0x00A1D8E2]
# 	(No symbol) [0x00A01F54]
# 	(No symbol) [0x00A1B49E]
# 	(No symbol) [0x00A01CA6]
# 	(No symbol) [0x009D31D5]
# 	(No symbol) [0x009D435D]
# 	GetHandleVerifier [0x00E307C3+3142947]
# 	GetHandleVerifier [0x00E41A2B+3213195]
# 	GetHandleVerifier [0x00E3C412+3191154]
# 	GetHandleVerifier [0x00BD8720+685184]
# 	(No symbol) [0x00AC6E1D]
# 	(No symbol) [0x00AC3E18]
# 	(No symbol) [0x00AC3FB6]
# 	(No symbol) [0x00AB66F0]
# 	BaseThreadInitThunk [0x75077BA9+25]
# 	RtlInitializeExceptionChain [0x76EBC0CB+107]
# 	RtlClearBits [0x76EBC04F+191]
#  28%|██▊       | 162/581 [04:51<22:31,  3.23s/it]
# Error procesando la URL https://www.pullandbear.com/es/jersey-cuello-cremallera-l07554517?cS=800: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00B374A3+25091]
# 	(No symbol) [0x00ABDC04]
# 	(No symbol) [0x0099B373]
# 	(No symbol) [0x009DF4DC]
# 	(No symbol) [0x009DF65B]
# 	(No symbol) [0x00A1D8E2]
# 	(No symbol) [0x00A01F54]
# 	(No symbol) [0x00A1B49E]
# 	(No symbol) [0x00A01CA6]
# 	(No symbol) [0x009D31D5]
# 	(No symbol) [0x009D435D]
# 	GetHandleVerifier [0x00E307C3+3142947]
# 	GetHandleVerifier [0x00E41A2B+3213195]
# 	GetHandleVerifier [0x00E3C412+3191154]
# 	GetHandleVerifier [0x00BD8720+685184]
# 	(No symbol) [0x00AC6E1D]
# 	(No symbol) [0x00AC3E18]
# 	(No symbol) [0x00AC3FB6]
# 	(No symbol) [0x00AB66F0]
# 	BaseThreadInitThunk [0x75077BA9+25]
# 	RtlInitializeExceptionChain [0x76EBC0CB+107]
# 	RtlClearBits [0x76EBC04F+191]
#  79%|███████▊  | 457/581 [14:24<06:08,  2.97s/it]
# Error procesando la URL https://www.pullandbear.com/es/jersey-cuello-perkins-l07554521?cS=251&pelement=630685215: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00B374A3+25091]
# 	(No symbol) [0x00ABDC04]
# 	(No symbol) [0x0099B373]
# 	(No symbol) [0x009DF4DC]
# 	(No symbol) [0x009DF65B]
# 	(No symbol) [0x00A1D8E2]
# 	(No symbol) [0x00A01F54]
# 	(No symbol) [0x00A1B49E]
# 	(No symbol) [0x00A01CA6]
# 	(No symbol) [0x009D31D5]
# 	(No symbol) [0x009D435D]
# 	GetHandleVerifier [0x00E307C3+3142947]
# 	GetHandleVerifier [0x00E41A2B+3213195]
# 	GetHandleVerifier [0x00E3C412+3191154]
# 	GetHandleVerifier [0x00BD8720+685184]
# 	(No symbol) [0x00AC6E1D]
# 	(No symbol) [0x00AC3E18]
# 	(No symbol) [0x00AC3FB6]
# 	(No symbol) [0x00AB66F0]
# 	BaseThreadInitThunk [0x75077BA9+25]
# 	RtlInitializeExceptionChain [0x76EBC0CB+107]
# 	RtlClearBits [0x76EBC04F+191]
#  82%|████████▏ | 475/581 [15:04<05:36,  3.18s/it]
# Error procesando la URL https://www.pullandbear.com/es/jeans-baggy-l08686518?cS=407&pelement=621935137: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00B374A3+25091]
# 	(No symbol) [0x00ABDC04]
# 	(No symbol) [0x0099B373]
# 	(No symbol) [0x009DF4DC]
# 	(No symbol) [0x009DF65B]
# 	(No symbol) [0x00A1D8E2]
# 	(No symbol) [0x00A01F54]
# 	(No symbol) [0x00A1B49E]
# 	(No symbol) [0x00A01CA6]
# 	(No symbol) [0x009D31D5]
# 	(No symbol) [0x009D435D]
# 	GetHandleVerifier [0x00E307C3+3142947]
# 	GetHandleVerifier [0x00E41A2B+3213195]
# 	GetHandleVerifier [0x00E3C412+3191154]
# 	GetHandleVerifier [0x00BD8720+685184]
# 	(No symbol) [0x00AC6E1D]
# 	(No symbol) [0x00AC3E18]
# 	(No symbol) [0x00AC3FB6]
# 	(No symbol) [0x00AB66F0]
# 	BaseThreadInitThunk [0x75077BA9+25]
# 	RtlInitializeExceptionChain [0x76EBC0CB+107]
# 	RtlClearBits [0x76EBC04F+191]
#  88%|████████▊ | 511/581 [16:19<03:46,  3.23s/it]
# Error procesando la URL https://www.pullandbear.com/es/camisa-boxy-pb-black-label-l03474500?cS=505&pelement=653047689: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00B374A3+25091]
# 	(No symbol) [0x00ABDC04]
# 	(No symbol) [0x0099B373]
# 	(No symbol) [0x009DF4DC]
# 	(No symbol) [0x009DF65B]
# 	(No symbol) [0x00A1D8E2]
# 	(No symbol) [0x00A01F54]
# 	(No symbol) [0x00A1B49E]
# 	(No symbol) [0x00A01CA6]
# 	(No symbol) [0x009D31D5]
# 	(No symbol) [0x009D435D]
# 	GetHandleVerifier [0x00E307C3+3142947]
# 	GetHandleVerifier [0x00E41A2B+3213195]
# 	GetHandleVerifier [0x00E3C412+3191154]
# 	GetHandleVerifier [0x00BD8720+685184]
# 	(No symbol) [0x00AC6E1D]
# 	(No symbol) [0x00AC3E18]
# 	(No symbol) [0x00AC3FB6]
# 	(No symbol) [0x00AB66F0]
# 	BaseThreadInitThunk [0x75077BA9+25]
# 	RtlInitializeExceptionChain [0x76EBC0CB+107]
# 	RtlClearBits [0x76EBC04F+191]
#  90%|█████████ | 524/581 [16:48<02:57,  3.11s/it]
# Error procesando la URL https://www.pullandbear.com/es/jersey-punto-estructura-l07554501?cS=800&pelement=621953892: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00B374A3+25091]
# 	(No symbol) [0x00ABDC04]
# 	(No symbol) [0x0099B373]
# 	(No symbol) [0x009DF4DC]
# 	(No symbol) [0x009DF65B]
# 	(No symbol) [0x00A1D8E2]
# 	(No symbol) [0x00A01F54]
# 	(No symbol) [0x00A1B49E]
# 	(No symbol) [0x00A01CA6]
# 	(No symbol) [0x009D31D5]
# 	(No symbol) [0x009D435D]
# 	GetHandleVerifier [0x00E307C3+3142947]
# 	GetHandleVerifier [0x00E41A2B+3213195]
# 	GetHandleVerifier [0x00E3C412+3191154]
# 	GetHandleVerifier [0x00BD8720+685184]
# 	(No symbol) [0x00AC6E1D]
# 	(No symbol) [0x00AC3E18]
# 	(No symbol) [0x00AC3FB6]
# 	(No symbol) [0x00AB66F0]
# 	BaseThreadInitThunk [0x75077BA9+25]
# 	RtlInitializeExceptionChain [0x76EBC0CB+107]
# 	RtlClearBits [0x76EBC04F+191]
#  92%|█████████▏| 532/581 [17:07<02:27,  3.00s/it]
# Error procesando la URL https://www.pullandbear.com/es/pantalon-jogger-tejido-premium-l07679508?cS=712&pelement=631016363: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00B374A3+25091]
# 	(No symbol) [0x00ABDC04]
# 	(No symbol) [0x0099B373]
# 	(No symbol) [0x009DF4DC]
# 	(No symbol) [0x009DF65B]
# 	(No symbol) [0x00A1D8E2]
# 	(No symbol) [0x00A01F54]
# 	(No symbol) [0x00A1B49E]
# 	(No symbol) [0x00A01CA6]
# 	(No symbol) [0x009D31D5]
# 	(No symbol) [0x009D435D]
# 	GetHandleVerifier [0x00E307C3+3142947]
# 	GetHandleVerifier [0x00E41A2B+3213195]
# 	GetHandleVerifier [0x00E3C412+3191154]
# 	GetHandleVerifier [0x00BD8720+685184]
# 	(No symbol) [0x00AC6E1D]
# 	(No symbol) [0x00AC3E18]
# 	(No symbol) [0x00AC3FB6]
# 	(No symbol) [0x00AB66F0]
# 	BaseThreadInitThunk [0x75077BA9+25]
# 	RtlInitializeExceptionChain [0x76EBC0CB+107]
# 	RtlClearBits [0x76EBC04F+191]
#  94%|█████████▍| 545/581 [17:38<01:53,  3.16s/it]
# Error procesando la URL https://www.pullandbear.com/es/camisa-cuadros-l07470504?cS=802&pelement=624983371: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00B374A3+25091]
# 	(No symbol) [0x00ABDC04]
# 	(No symbol) [0x0099B373]
# 	(No symbol) [0x009DF4DC]
# 	(No symbol) [0x009DF65B]
# 	(No symbol) [0x00A1D8E2]
# 	(No symbol) [0x00A01F54]
# 	(No symbol) [0x00A1B49E]
# 	(No symbol) [0x00A01CA6]
# 	(No symbol) [0x009D31D5]
# 	(No symbol) [0x009D435D]
# 	GetHandleVerifier [0x00E307C3+3142947]
# 	GetHandleVerifier [0x00E41A2B+3213195]
# 	GetHandleVerifier [0x00E3C412+3191154]
# 	GetHandleVerifier [0x00BD8720+685184]
# 	(No symbol) [0x00AC6E1D]
# 	(No symbol) [0x00AC3E18]
# 	(No symbol) [0x00AC3FB6]
# 	(No symbol) [0x00AB66F0]
# 	BaseThreadInitThunk [0x75077BA9+25]
# 	RtlInitializeExceptionChain [0x76EBC0CB+107]
# 	RtlClearBits [0x76EBC04F+191]
#  98%|█████████▊| 568/581 [18:26<00:40,  3.09s/it]
# Error procesando la URL https://www.pullandbear.com/es/bermuda-jogger-interlock-l07693508?cS=800&pelement=621935058: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00B374A3+25091]
# 	(No symbol) [0x00ABDC04]
# 	(No symbol) [0x0099B373]
# 	(No symbol) [0x009DF4DC]
# 	(No symbol) [0x009DF65B]
# 	(No symbol) [0x00A1D8E2]
# 	(No symbol) [0x00A01F54]
# 	(No symbol) [0x00A1B49E]
# 	(No symbol) [0x00A01CA6]
# 	(No symbol) [0x009D31D5]
# 	(No symbol) [0x009D435D]
# 	GetHandleVerifier [0x00E307C3+3142947]
# 	GetHandleVerifier [0x00E41A2B+3213195]
# 	GetHandleVerifier [0x00E3C412+3191154]
# 	GetHandleVerifier [0x00BD8720+685184]
# 	(No symbol) [0x00AC6E1D]
# 	(No symbol) [0x00AC3E18]
# 	(No symbol) [0x00AC3FB6]
# 	(No symbol) [0x00AB66F0]
# 	BaseThreadInitThunk [0x75077BA9+25]
# 	RtlInitializeExceptionChain [0x76EBC0CB+107]
# 	RtlClearBits [0x76EBC04F+191]
# 100%|██████████| 581/581 [18:53<00:00,  1.95s/it]
# Resultados:
# (627, 16)
# Resultados sin duplicados:
# (551, 16)
#                  product_name  \
# 0    Camiseta Bialetti blanca
# 1              Camiseta Honda
# 2     Camiseta Sakamoto Store
# 3  Camiseta básica muscle fit
# 4  Camiseta básica muscle fit
#
#                                                  url  \
# 0  https://www.pullandbear.com/es/camiseta-bialet...
# 1  https://www.pullandbear.com/es/camiseta-honda-...
# 2  https://www.pullandbear.com/es/camiseta-sakamo...
# 3  https://www.pullandbear.com/es/camiseta-basica...
# 4  https://www.pullandbear.com/es/camiseta-basica...
#
#                                           image1_url  \
# 0  https://static.pullandbear.net/assets/public/f...
# 1  https://static.pullandbear.net/assets/public/f...
# 2  https://static.pullandbear.net/assets/public/8...
# 3  https://static.pullandbear.net/assets/public/4...
# 4  https://static.pullandbear.net/assets/public/3...
#
#                                           image2_url  product_price  \
# 0  https://static.pullandbear.net/assets/public/d...          15.99
# 1  https://static.pullandbear.net/2/photos//2025/...          15.99
# 2  https://static.pullandbear.net/assets/public/c...          17.99
# 3  https://static.pullandbear.net/assets/public/f...           7.99
# 4  https://static.pullandbear.net/assets/public/5...           7.99
#
#                                          description  sale_price  old_price  \
# 0  Camiseta blanca licencia Bialetti con bordado ...         NaN        NaN
# 1  Camiseta de manga corta blanca y cuello redond...         NaN        NaN
# 2  Camiseta blanca licencia Sakamoto con gráfico,...         NaN        NaN
# 3  MUSCLE FIT. Camiseta básica de manga corta, co...         NaN        NaN
# 4  MUSCLE FIT. Camiseta básica de manga corta, co...         NaN        NaN
#
#    original_price  current_price        color  \
# 0             NaN          15.99       Blanco
# 1             NaN          15.99       Blanco
# 2             NaN          17.99  Blanco roto
# 3             NaN           7.99       Blanco
# 4             NaN           7.99        Negro
#
#                                            image_url       mpn reference_code  \
# 0  https://static.pullandbear.net/assets/public/5...  3248/537       03248537
# 1  https://static.pullandbear.net/assets/public/7...  3245/519       03245519
# 2  https://static.pullandbear.net/assets/public/0...  3245/539       03245539
# 3  https://static.pullandbear.net/assets/public/4...  3245/502       03245502
# 4  https://static.pullandbear.net/assets/public/0...  3245/502       03245502
#
#   category_id Stock Status
# 0  1030139501     In stock
# 1  1030139501     In stock
# 2  1030139501     In stock
# 3  1030204791     In stock
# 4  1030204791     In stock

# %% [markdown]
# # HOMOGENEIZAR LOS DATOS

# %% [markdown]
# ### COLOR

# %%
# Crear una nueva columna con el color homogeneizado
df_sin_duplicados['color_homogeneizado'] = df_sin_duplicados['color'].apply(ss.homogeneizar_color)
# Out:
# C:\Users\alexc\AppData\Local\Temp\ipykernel_14716\3346448002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados['color_homogeneizado'] = df_sin_duplicados['color'].apply(ss.homogeneizar_color)

# %% [markdown]
# ### CATEGORÍA

# %%
# Crear una nueva columna con la categoría de la prenda
df_sin_duplicados['Categoria'] = df_sin_duplicados['product_name'].apply(ss.categorizar_ropa)

# Mostrar las primeras filas para comprobar
df_sin_duplicados[['product_name', 'Categoria']].sample(5)
# Out:
# C:\Users\alexc\AppData\Local\Temp\ipykernel_14716\448092441.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados['Categoria'] = df_sin_duplicados['product_name'].apply(ss.categorizar_ropa)
#                        product_name Categoria
# 151         Camisa boxy manga larga    Camisa
# 349        Pantalón jogger con lino  Pantalón
# 575                     Jeans baggy  Pantalón
# 234    Sudadera cuello redondo STWD  Sudadera
# 211  Sudadera El triunfo de Galatea  Sudadera

# %% [markdown]
# ### CONTROL URLs FALTANTES

# %%
# Asignar "out of stock" a la columna 'Stock Status' donde 'image_url' sea vacío o nulo
df_sin_duplicados.loc[(df_sin_duplicados['image_url'].isna()) | (df_sin_duplicados['image_url'] == ''), 'Stock Status'] = 'Out of Stock'

# %% [markdown]
# ### GUARDAR CSV

# %%
# Filtrar los pantalones para coger los modelos de cuerpo entero
df_modelos = df_sin_duplicados[(df_sin_duplicados['Categoria'] == 'Pantalón')]
df_modelos["Fondo"] =df_modelos["image1_url"].apply(sfm.is_white_background)
df_modelos["Modelo"] =df_modelos["image1_url"].apply(sfm.classify_image)
df_modelos_final=df_modelos[(df_modelos["Fondo"] == "Blanco")&(df_modelos["Modelo"] == "Modelo")&(df_modelos["Stock Status"] == "In stock")]
# Out:
# Intento 1 fallido: Error en URL: https://static.pullandbear.net/assets/public/193a/fac1/a16b4243a8ea/bc83c61c56b7/03680524251-M/03680524251-M.jpg?ts=1738832883710&w=438&f=auto (Código 403)
# Intento 2 fallido: Error en URL: https://static.pullandbear.net/assets/public/193a/fac1/a16b4243a8ea/bc83c61c56b7/03680524251-M/03680524251-M.jpg?ts=1738832883710&w=438&f=auto (Código 403)
# Intento 3 fallido: Error en URL: https://static.pullandbear.net/assets/public/193a/fac1/a16b4243a8ea/bc83c61c56b7/03680524251-M/03680524251-M.jpg?ts=1738832883710&w=438&f=auto (Código 403)
# Intento 1 fallido: Error en URL: https://static.pullandbear.net/assets/public/1155/68a1/90ff40ffad12/85c1ab229b9c/03680508251-M/03680508251-M.jpg?ts=1738683240043&w=438&f=auto (Código 403)
# Intento 2 fallido: Error en URL: https://static.pullandbear.net/assets/public/1155/68a1/90ff40ffad12/85c1ab229b9c/03680508251-M/03680508251-M.jpg?ts=1738683240043&w=438&f=auto (Código 403)
# Intento 3 fallido: Error en URL: https://static.pullandbear.net/assets/public/1155/68a1/90ff40ffad12/85c1ab229b9c/03680508251-M/03680508251-M.jpg?ts=1738683240043&w=438&f=auto (Código 403)
# Intento 1 fallido: Error en URL: https://static.pullandbear.net/assets/public/6d62/0a8f/3dd04c9d9f8b/f23f2ce25902/03680508710-M/03680508710-M.jpg?ts=1738683244472&w=438&f=auto (Código 403)
# Intento 2 fallido: Error en URL: https://static.pullandbear.net/assets/public/6d62/0a8f/3dd04c9d9f8b/f23f2ce25902/03680508710-M/03680508710-M.jpg?ts=1738683244472&w=438&f=auto (Código 403)
# Intento 3 fallido: Error en URL: https://static.pullandbear.net/assets/public/6d62/0a8f/3dd04c9d9f8b/f23f2ce25902/03680508710-M/03680508710-M.jpg?ts=1738683244472&w=438&f=auto (Código 403)
# Intento 1 fallido: Error en URL: https://static.pullandbear.net/assets/public/1339/110e/f936458695ad/644eb24f6236/03680508807-M/03680508807-M.jpg?ts=1738683249604&w=438&f=auto (Código 403)
# Intento 2 fallido: Error en URL: https://static.pullandbear.net/assets/public/1339/110e/f936458695ad/644eb24f6236/03680508807-M/03680508807-M.jpg?ts=1738683249604&w=438&f=auto (Código 403)
# Intento 3 fallido: Error en URL: https://static.pullandbear.net/assets/public/1339/110e/f936458695ad/644eb24f6236/03680508807-M/03680508807-M.jpg?ts=1738683249604&w=438&f=auto (Código 403)
# Intento 1 fallido: Error en URL: https://static.pullandbear.net/assets/public/4ad5/2d8a/3f5747d7bb95/6f0be1be6a34/03680508832-M/03680508832-M.jpg?ts=1738683254433&w=438&f=auto (Código 403)
# Intento 2 fallido: Error en URL: https://static.pullandbear.net/assets/public/4ad5/2d8a/3f5747d7bb95/6f0be1be6a34/03680508832-M/03680508832-M.jpg?ts=1738683254433&w=438&f=auto (Código 403)
# Intento 3 fallido: Error en URL: https://static.pullandbear.net/assets/public/4ad5/2d8a/3f5747d7bb95/6f0be1be6a34/03680508832-M/03680508832-M.jpg?ts=1738683254433&w=438&f=auto (Código 403)
# C:\Users\alexc\AppData\Local\Temp\ipykernel_14716\4263403506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_modelos["Fondo"] =df_modelos["image1_url"].apply(sfm.is_white_background)
# 0: 640x448 1 person, 134.9ms
# Speed: 12.2ms preprocess, 134.9ms inference, 14.4ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.0ms
# Speed: 2.4ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.3ms
# Speed: 2.4ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.4ms
# Speed: 1.0ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.8ms
# Speed: 2.0ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 53.7ms
# Speed: 2.0ms preprocess, 53.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.2ms
# Speed: 2.3ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 53.3ms
# Speed: 2.4ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.4ms
# Speed: 4.0ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 53.6ms
# Speed: 2.2ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.0ms
# Speed: 2.5ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.4ms
# Speed: 2.0ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.3ms
# Speed: 2.4ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.5ms
# Speed: 2.2ms preprocess, 56.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.2ms
# Speed: 2.0ms preprocess, 56.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.6ms
# Speed: 3.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.6ms
# Speed: 2.4ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.2ms
# Speed: 1.0ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 tie, 57.8ms
# Speed: 2.0ms preprocess, 57.8ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.2ms
# Speed: 2.1ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.1ms
# Speed: 2.1ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.9ms
# Speed: 3.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.1ms
# Speed: 1.0ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 102.1ms
# Speed: 2.0ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 tie, 57.3ms
# Speed: 2.0ms preprocess, 57.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.8ms
# Speed: 2.0ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 52.7ms
# Speed: 2.0ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.2ms
# Speed: 2.3ms preprocess, 56.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.9ms
# Speed: 2.0ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 tie, 57.4ms
# Speed: 2.1ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.2ms
# Speed: 2.0ms preprocess, 54.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 69.5ms
# Speed: 2.0ms preprocess, 69.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.2ms
# Speed: 2.0ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.2ms
# Speed: 2.0ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 66.2ms
# Speed: 2.0ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.2ms
# Speed: 2.0ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 66.9ms
# Speed: 3.0ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 52.5ms
# Speed: 2.1ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 53.5ms
# Speed: 2.3ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 102.2ms
# Speed: 1.1ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.4ms
# Speed: 2.0ms preprocess, 54.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.6ms
# Speed: 2.2ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 53.2ms
# Speed: 1.0ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.0ms
# Speed: 3.1ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 2 ties, 53.9ms
# Speed: 2.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.2ms
# Speed: 1.0ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.1ms
# Speed: 2.2ms preprocess, 59.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.2ms
# Speed: 3.3ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.3ms
# Speed: 2.0ms preprocess, 54.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.3ms
# Speed: 2.4ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.2ms
# Speed: 2.0ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.7ms
# Speed: 3.0ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.9ms
# Speed: 2.5ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 66.6ms
# Speed: 1.5ms preprocess, 66.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.6ms
# Speed: 8.0ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.4ms
# Speed: 1.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 63.6ms
# Speed: 3.0ms preprocess, 63.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.4ms
# Speed: 2.3ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.9ms
# Speed: 2.1ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.7ms
# Speed: 2.0ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.0ms
# Speed: 1.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.7ms
# Speed: 2.0ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.7ms
# Speed: 2.0ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.0ms
# Speed: 1.2ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 56.6ms
# Speed: 1.2ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.6ms
# Speed: 1.0ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.5ms
# Speed: 2.5ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 55.5ms
# Speed: 2.3ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.3ms
# Speed: 2.0ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 61.5ms
# Speed: 1.0ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# C:\Users\alexc\AppData\Local\Temp\ipykernel_14716\4263403506.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_modelos["Modelo"] =df_modelos["image1_url"].apply(sfm.classify_image)

# %%
# Guardar el nuevo DataFrame con pantalones en un archivo CSV
df_modelos_final.to_csv('../results/Modelos_enteros.csv', index=False)
df_modelos.to_csv('../results/Modelos_entero_sin_filtro.csv', index=False)

# Guardar los cambios en un archivo nuevo si lo necesitas
df_sin_duplicados.to_csv('../results/all_products_info_with_categories.csv', index=False)

# %% [markdown]
# ### SUBIR A MONGODB

# %%
# Guardamos los datos en la bbdd de Mongo
bd=sm.conectar_a_mongo("PullnBearData")
nombre_coleccion1="modelos_pull_hombre"
nombre_coleccion2="productos_pull_hombre"
sm.eliminar_coleccion(bd, nombre_coleccion1)
sm.subir_dataframe_a_mongo(bd, df_modelos_final, nombre_coleccion1)
sm.eliminar_coleccion(bd, nombre_coleccion2)
sm.subir_dataframe_a_mongo(bd, df_sin_duplicados, nombre_coleccion2)
# Out:
# DataFrame subido a la colección: modelos_pull_hombre
# DataFrame subido a la colección: productos_pull_hombre
